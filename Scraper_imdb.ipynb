# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def get_imdb_stuff(movie_codes):
    
    movies_imdb = [['title', 'year', 'mpaa', 'run_time', 'rating', 'ratings_count', 'budget', 'world_gross', 'genre', 'director', 
                   'writer', 'actor', 'keywords', 'summary', 'synopsis']]
    
    for movie_code in movie_codes:
        
        movie_id = str(movie_code)
        
        try:
            
            #synopsis
            synopsis = 'https://www.imdb.com/title/' + movie_id + '/plotsummary'
            page = requests.get(synopsis)
            soup = BeautifulSoup(page.text, 'html.parser')
            
            synopsis = soup.find('ul', id="plot-synopsis-content").get_text(strip=True)
            
            imdb_title = 'https://www.imdb.com/title/' + movie_id + '/' 
            imdb_page = requests.get(imdb_title)
            imdb_soup = BeautifulSoup(imdb_page.text, 'html.parser')
            
            #get title and year
            main = imdb_soup.find('h1', class_='').get_text(strip=True)
            title = main.split('(')[0]
            year = main.split('(')[1].replace(')', '')
            
            
            #get rating
            rating = imdb_soup.find('span', itemprop='ratingValue').text
            ratings_count = imdb_soup.find('span', itemprop='ratingCount').text

            #get summary
            summary = imdb_soup.find('div', class_='summary_text').get_text(strip=True) 
            
            #get cast
            credits = imdb_soup.find_all('div', class_='credit_summary_item')

            credits = [credit.get_text(strip=True) for credit in credits]

            director = credits[0].split(':')[1].split('|')[0]
            writer = credits[1].split(':')[1].split('|')[0]
            actor = credits[2].split(':')[1].split('|')[0]
                
            misc_data = imdb_soup.find_all('div', class_='txt-block')
            misc_data = [line.get_text(strip=True) for line in misc_data]
            
            #get mpaa
            mpaas = ['G', 'PG', 'R', 'PG-13']
            mpaa = None
            for line in misc_data:
                for mpaa_ in mpaas:
                    if mpaa_ in line.split():
                        mpaa = mpaa_
            #budget            
            budget = None
            for line in misc_data:
                if 'Budget' in line:
                    budget = ''.join([ch for ch in line if ch.isdigit()])
                    
            #revenue        
            world_gross = None
            for line in misc_data:
                if 'Worldwide' in line:
                    world_gross = ''.join([ch for ch in line if ch.isdigit()])
            
            #runtime
            run_time = None
            for line in misc_data:
                if 'Runtime' in line:
                    run_time = ''.join([ch for ch in line if ch.isdigit()])
                    
            #genres and keywords
            genres = imdb_soup.find_all('div', class_='see-more inline canwrap')
            genres = [genre.get_text(strip=True) for genre in genres]
            
            keywords = None
            for line in genres:
                if 'Plot Keywords:' in line:
                    keywords = line.replace(':', '|').split('|')[1:-1]
                    
            genre = None
            for line in genres:
                if 'Genres' in line:
                    genre = line.replace(':', '|').split('|')[1:]

            
            movies_imdb.append([title, year, mpaa, run_time, rating, ratings_count, budget, world_gross, genre, director, 
                   writer, actor, keywords, summary, synopsis])
            
        except:
            continue
    
    return movies_imdb

# %%
df = pd.read_csv('imdb_codes.csv')
df.head()
# Out:
#       tconst                   primaryTitle                  originalTitle  \
# 0  tt0000009                     Miss Jerry                     Miss Jerry
# 1  tt0000147  The Corbett-Fitzsimmons Fight  The Corbett-Fitzsimmons Fight
# 2  tt0000335          Soldiers of the Cross          Soldiers of the Cross
# 3  tt0000502                       Bohemios                       Bohemios
# 4  tt0000574    The Story of the Kelly Gang    The Story of the Kelly Gang
#
#    startYear runtimeMinutes                  genres
# 0       1894             45                 Romance
# 1       1897             20  Documentary,News,Sport
# 2       1900             \N         Biography,Drama
# 3       1905            100                      \N
# 4       1906             70   Biography,Crime,Drama

# %%
df = df[df['runtimeMinutes'] != '\\N']
df.runtimeMinutes = df.runtimeMinutes.astype('int64')
df = df[df['runtimeMinutes'] >= 80]

# %%
movie_codes = df[df['startYear'] >= 1990]
movie_list = list(movie_codes.tconst)
len(movie_list)
# Out:
# 145304

# %%
import time
start_time = time.time()

film = get_imdb_stuff(movie_list)

print("--- %s ---" % time.strftime('%H:%M:%S', time.gmtime((time.time() - start_time))))
# Out:
# --- 23:34:08 ---

# %%
movies = pd.DataFrame(film, columns=film[0])
movies.drop(0, axis=0, inplace=True)
movies.to_csv('imdb_data_update.csv', index=False)
print(movies.shape)
movies
# Out:
# (96695, 15)
#                            title  year   mpaa run_time rating ratings_count  \
# 1                  Dama de noche  1993   None     None    6.2            20
# 2                 Kate & Leopold  2001  PG-13   118123    6.4        77,418
# 3       The Woman with the Knife  2010   None       80    6.6            10
# 4        Vojtech, receny sirotek  1990   None       80    6.5            24
# 5                           Ucho  1990   None       94    7.8         2,367
# ...                          ...   ...    ...      ...    ...           ...
# 96691  Padmavyuhathile Abhimanyu  2019   None      130    7.9           264
# 96692                 No Apology  2019   None      102    5.2            32
# 96693                   Paradise  2019   None      135    8.2            18
# 96694          Sokagin Çocuklari  2019   None       98    6.4           194
# 96695        Kuambil Lagi Hatiku  2019   None      123    8.4             5
#
#          budget world_gross                                genre  \
# 1          None        None  [Drama, Mystery, Romance, Thriller]
# 2      48000000    76019048           [Comedy, Fantasy, Romance]
# 3          None        None                    [Drama, Thriller]
# 4          None        None                              [Drama]
# 5          None        None                    [Drama, Thriller]
# ...         ...         ...                                  ...
# 96691      None        None                              [Drama]
# 96692      None        None                              [Drama]
# 96693      None        None                       [Crime, Drama]
# 96694      None        2833                      [Drama, Family]
# 96695      None        None                              [Drama]
#
#                    director  \
# 1         Eva López Sánchez
# 2             James Mangold
# 3            Bassori Timite
# 4                Zdenek Tyc
# 5             Karel Kachyna
# ...                     ...
# 96691       Vineesh Aaradya
# 96692         Gilbert Allan
# 96693  Kevin Jimenez Bernal
# 96694     Ahmet Faik Akinci
# 96695     Azhar Kinoi Lubis
#
#                                                   writer  \
# 1        Eva López Sánchez,David Martin del Campo(novel)
# 2         Steven Rogers(story),James Mangold(screenplay)
# 3                      Bassori Timite(as Timité Bassori)
# 4      Jaromir Kacer(screenplay),Jirí Soukup(screenplay)
# 5                Karel Kachyna,Jan Procházka(screenplay)
# ...                                                  ...
# 96691  Vineesh Aaradya(screenplay),Vineesh Aaradya(st...
# 96692                                     Casey Richards
# 96693                               Kevin Jimenez Bernal
# 96694                      Ahmet Faik Akinci,Kasim Uçkan
# 96695  Arief Ash Siddiq(script writer),Rino Sarjono(s...
#
#                                                    actor  \
# 1      Rafael Sánchez Navarro,Cecilia Toussaint,Migue...
# 2                   Meg Ryan,Hugh Jackman,Liev Schreiber
# 3              Bassori Timite,Mary Vieyra,Danielle Alloh
# 4             Petr Forman,Barbora Lukesová,Jana Riháková
# 5      Jirina Bohdalová,Radoslav Brzobohatý,Gustav Op...
# ...                                                  ...
# 96691                   Anoop Chandran,Indrans,Sona Nair
# 96692              Lydia Adair,Owen Bishop,Pierce Briggs
# 96693  Kevin Jimenez Bernal,Feli Cabrera,Olivier Lukunku
# 96694        Ahmet Faik Akinci,Belma Mamati,Metin Keçeci
# 96695              Lala Karmela,Cut Mini Theo,Sahil Shah
#
#                                                 keywords  \
# 1      [f rated, older man younger woman relationship...
# 2      [time travel, brooklyn bridge, bridge, time tr...
# 3                                               [sexual]
# 4      [skinny dipping, male nudity, male frontal nud...
# 5      [czech new wave, sleeplessness, power failure,...
# ...                                                  ...
# 96691                                               None
# 96692                                            [death]
# 96693                                            [money]
# 96694                                               None
# 96695                                               None
#
#                                                  summary  \
# 1                                            Add a Plot»
# 2      An English Duke from 1876 is inadvertedly drag...
# 3      A young man returns from Europe obsessed with ...
# 4                                            Add a Plot»
# 5      After coming home from a Party gathering one n...
# ...                                                  ...
# 96691                                        Add a Plot»
# 96692  When a group of women struggle to deal with th...
# 96693  Five years after Diego ended school he finds h...
# 96694                                        Add a Plot»
# 96695  Agra City, India, will be the witness to the m...
#
#                                                 synopsis
# 1      It looks like we don't have a Synopsis for thi...
# 2      In 1876, Leopold Alexis Elijah Walker Gareth T...
# 3      It looks like we don't have a Synopsis for thi...
# 4      It looks like we don't have a Synopsis for thi...
# 5      It looks like we don't have a Synopsis for thi...
# ...                                                  ...
# 96691  It looks like we don't have a Synopsis for thi...
# 96692  It looks like we don't have a Synopsis for thi...
# 96693  It looks like we don't have a Synopsis for thi...
# 96694  It looks like we don't have a Synopsis for thi...
# 96695  It looks like we don't have a Synopsis for thi...
#
# [96695 rows x 15 columns]

# %%
movies.head(40)
# Out:
#                                    title  year  mpaa run_time rating  \
# 1                               La clase  2007  None     None    6.8
# 2                                Extract  2009     R       92    6.1
# 3                  Extraordinary Stories  2008  None     None    8.0
# 4                         Hype Nation 3D  2014  None       84    5.6
# 5                                 Retina  2017  None       87    5.6
# 6         Yo-rhad, un amico dallo spazio  2006  None     None    2.9
# 7                      The Hungry Ghosts  2009     R      105    5.1
# 8                     Chi nasce tondo...  2008  None       85    6.1
# 9                   Get Him to the Greek  2010     R   109114    6.4
# 10                          The Greatest  2009     R     9996    6.6
# 11                       Io sono l'amore  2009     R      120    7.0
# 12                        A Late Quartet  2012     R      105    7.1
# 13                             Mistéryos  2008  None     None    4.8
# 14                           Now Showing  2008  None      280    6.4
# 15          Pokémon: The Rise of Darkrai  2007  None       95    6.4
# 16                    An Unlikely Weapon  2008  None     None    7.8
# 17       Yai Wanonabalewa: The Enemy God  2008  None   100100    7.3
# 18                     The Damned United  2009     R       98    7.5
# 19                      Edge of Darkness  2010     R      117    6.6
# 20                        Happy New Year  2011  None     None    6.1
# 21                   Bob and the Monster  2011  None       87    7.6
# 22                        Dernier maquis  2008  None       93    6.7
# 23                       Niu lang zhi nu  2008  None   100100    7.5
# 24               Taraneh tanhaïye Tehran  2008  None       75    7.2
# 25                     Monsieur Morimoto  2008  None     None    7.6
# 26                               Shultes  2008  None     None    6.0
# 27                       Private Lessons  2008  None     None    6.2
# 28                             Pontypool  2008  None     9395    6.6
# 29                                  1234  2008  None       82    5.0
# 30                    Alexander Jamieson  2017  None      135    8.8
# 31                          Alphonso Bow  2010  None       72    5.8
# 32                           Brainjacked  2009  None       93    5.8
# 33                              The Debt  2010     R      113    6.8
# 34               The Great Gilly Hopkins  2015    PG       99    6.5
# 35                       He's on My Mind  2009  None     None    3.7
# 36                           In the Loop  2009  None      106    7.4
# 37                            Loved Ones  2008  None       92    6.0
# 38  Sartoria Tirelli - Vestire il cinema  2006  None       54    5.0
# 39                          Spark Riders  2010  None     None    7.2
# 40                         Beautiful Boy  2018     R      120    7.3
#
#    ratings_count    budget world_gross  \
# 1             17      None        None
# 2         43,970   8000000    10848783
# 3            962      None        None
# 4             17  25000000        None
# 5            646      None       41280
# 6             11      None        None
# 7            167      None        None
# 8             78   1500000       33486
# 9        167,098  40000000    91720255
# 10         8,477   6000000     1344544
# 11        19,787   3600000    12014663
# 12        13,583      None     6303709
# 13            24   2000000        None
# 14            54      None        None
# 15         2,763      None    42496749
# 16            90   1000000        None
# 17            30   1400000        None
# 18        40,400  10000000     4091378
# 19        88,181  80000000    81126522
# 20           106      None       14874
# 21           242      None        None
# 22           150      None      213304
# 23            46      None       10144
# 24            40      None        None
# 25            17      None        None
# 26           308      None       23088
# 27           865      None      194766
# 28        28,330   1500000       32118
# 29           115    500000        None
# 30             6   1000000        None
# 31            20    100000        None
# 32            57      None        None
# 33        63,036  20000000    45636368
# 34         4,324   5000000       97798
# 35           200      None        None
# 36        53,384    612650     7787487
# 37            25    100000        None
# 38             7      None        None
# 39            13    200000        None
# 40        46,687  25000000    16636604
#
#                                                 genre  \
# 1                                             [Drama]
# 2                            [Comedy, Crime, Romance]
# 3                                    [Drama, Mystery]
# 4                             [Drama, Music, Musical]
# 5                                   [Drama, Thriller]
# 6                                         [Animation]
# 7                                             [Drama]
# 8                                            [Comedy]
# 9                                     [Comedy, Music]
# 10                                   [Drama, Romance]
# 11                                   [Drama, Romance]
# 12                                     [Drama, Music]
# 13                                          [Mystery]
# 14                                            [Drama]
# 15  [Animation, Action, Adventure, Comedy, Drama, ...
# 16                                      [Documentary]
# 17                                            [Drama]
# 18                          [Biography, Drama, Sport]
# 19                  [Crime, Drama, Mystery, Thriller]
# 20                                       [Drama, War]
# 21                                      [Documentary]
# 22                                            [Drama]
# 23                                            [Drama]
# 24                                            [Drama]
# 25                                               None
# 26                                     [Crime, Drama]
# 27                                            [Drama]
# 28                        [Fantasy, Horror, Thriller]
# 29                    [Comedy, Drama, Music, Romance]
# 30                                 [Adventure, Drama]
# 31                                    [Comedy, Drama]
# 32                                   [Horror, Sci-Fi]
# 33                                  [Drama, Thriller]
# 34                            [Comedy, Drama, Family]
# 35                                  [Comedy, Romance]
# 36                                           [Comedy]
# 37                                           [Horror]
# 38                                      [Documentary]
# 39                                           [Sci-Fi]
# 40                                 [Biography, Drama]
#
#                                             director  \
# 1                                José Antonio Varela
# 2                                         Mike Judge
# 3                                     Mariano Llinás
# 4              Alan Calzatti,Christian A. Strickland
# 5                                      Carlos Ferrer
# 6                     Vittorio Rambaldi,Camillo Teti
# 7                                  Michael Imperioli
# 8                                  Alessandro Valori
# 9                                   Nicholas Stoller
# 10                                       Shana Feste
# 11                                   Luca Guadagnino
# 12                                   Yaron Zilberman
# 13                      Beto Carminatti,Pedro Merege
# 14                                       Raya Martin
# 15                                   Kunihiko Yuyama
# 16              Susan Morgan Cooper(as Susan Morgan)
# 17  Christopher M. Bessette(as Christopher Bessette)
# 18                                        Tom Hooper
# 19                                   Martin Campbell
# 20                                 K. Lorrel Manning
# 21                                    Keirda Bahruth
# 22                              Rabah Ameur-Zaïmeche
# 23                                       Lichuan Yin
# 24                                       Saman Salur
# 25                                    Nicola Sornaga
# 26                                   Bakur Bakuradze
# 27                                   Joachim Lafosse
# 28                                    Bruce McDonald
# 29                                        Giles Borg
# 30                                    Brad Batchelor
# 31                                        Lije Sarki
# 32                                      Andrew Allan
# 33                                       John Madden
# 34                                     Stephen Herek
# 35                                     Kazeem Molake
# 36                                  Armando Iannucci
# 37                                        Shawn Cain
# 38                                 Gianfranco Giagni
# 39                                      Douglas Neff
# 40                              Felix van Groeningen
#
#                                                writer  \
# 1   Rafael Pinto(as Rafael Antonio),José Antonio V...
# 2                                          Mike Judge
# 3                                      Mariano Llinás
# 4                   Jason Lee(screenplay),Daniel Shin
# 5                 Carlos Ferrer(story and screenplay)
# 6          Gina Basso(novel),Vittorio Rambaldi(novel)
# 7                                   Michael Imperioli
# 8   Adamo Dionisi(screenplay),Valerio Mastandrea(s...
# 9            Nicholas Stoller,Jason Segel(characters)
# 10                                        Shana Feste
# 11  Barbara Alberti(screenplay),Ivan Cotroneo(scre...
# 12  Seth Grossman(screenplay),Yaron Zilberman(scre...
# 13                         Gil Baroni,Beto Carminatti
# 14                            Raya Martin(screenplay)
# 15  Junichi Masuda(creator),Hideki Sonoda(screenplay)
# 16  Susan Morgan Cooper(screenplay) (as Susan Morgan)
# 17   Christopher M. Bessette(as Christopher Bessette)
# 18        Peter Morgan(screenplay),David Peace(novel)
# 19  William Monahan(screenplay),Andrew Bovell(scre...
# 20  Michael Cuomo(story),K. Lorrel Manning(screenp...
# 21                                     Keirda Bahruth
# 22                Rabah Ameur-Zaïmeche,Louise Thermes
# 23       Mei Ah(screenwriter),Lichuan Yin(screenplay)
# 24                            Saman Salur(screenplay)
# 25                   Nicola Sornaga,Salvatore Sansone
# 26                        Bakur Bakuradze(screenplay)
# 27  Joachim Lafosse(screenplay),François Pirot(scr...
# 28                   Tony Burgess,Tony Burgess(novel)
# 29                                         Giles Borg
# 30                                     Brad Batchelor
# 31                                           M. Sarki
